# %%
# WeatherPy
----

### Analysis
* As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
* There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
* There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.

Based on the data given, there were some observable trends.  
One of the observations is that there is an increase in temperature for cities situated near the equator and a sharp decrease in temperature for cities further south of the equator.  
Another observation is that the highest temperatures are presented in cities between the Tropic of Cancer and Tropic of Capricorn.  Finally, after analyzing the scatterplots for 
latitude vs. humidity, latitude vs. cloudiness, and latitude vs. wind speed, we can conclude the are no solid linear relationship between latitude vs. humidity, cloudiness, and wind speed.
---

#### Note
* Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key
import api_keys
# Incorporated citipy to determine city based on latitude and longitude

from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 607

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# OpenWeatherMap API Key
api_key = api_keys.api_key

# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key

# url = "http://api.openweathermap.org/data/2.5/forecast?id=524901&APPID=" + api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
 # Create empty lists to append the API data into lists 
city_name = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
max_temp = []
wind_speed = []

# Start the call counter 
record = 1

# Log file print statement
print(f"Beginning Data Retrieval")
print(f"-------------------------------")

#Loop through the cities in the city list 
for city in cities:  
    
# Try statement to append calls where value is found 
# Not all calls return data as OpenWeatherMap will not have have records in all the cities generated by CityPy module
    try: 
        response = requests.get(f"{url}&q={city}").json() 
        city_name.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        max_temp.append(response["main"]["temp_max"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        wind_speed.append(response["wind"]["speed"])
        city_record = response["name"]
        print(f"Processing Record {record} | {city_record}")
        print(f"{url}&q={city}")
        
# Increase counter by one 
        record= record + 1
        
# Wait a second in loop to not over exceed rate limit of API
        time.sleep(1.01)
        
# If no record found "skip" to next call
    except:
        print("City not found. Skipping...")
    continue
# Out:
# Beginning Data Retrieval
# -------------------------------
# Processing Record 1 | Matamoros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=matamoros
# Processing Record 2 | Busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=busselton
# Processing Record 3 | Poum
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=poum
# City not found. Skipping...
# Processing Record 4 | Codrington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=codrington
# Processing Record 5 | Cape Town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=cape town
# Processing Record 6 | Hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=hilo
# Processing Record 7 | Vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=vaini
# Processing Record 8 | Pangody
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=pangody
# Processing Record 9 | Bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=bluff
# Processing Record 10 | Butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=butaritari
# Processing Record 11 | Tricase
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=tricase
# Processing Record 12 | Warmbad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=warmbad
# Processing Record 13 | Jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=jamestown
# Processing Record 14 | Nuuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=nuuk
# Processing Record 15 | Klaksvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=klaksvik
# Processing Record 16 | Qiongshan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=qiongshan
# City not found. Skipping...
# Processing Record 17 | Puerto Cabello
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=puerto cabello
# Processing Record 18 | Pinsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=pinsk
# Processing Record 19 | Ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=ostrovnoy
# Processing Record 20 | Saint Anthony
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=saint anthony
# Processing Record 21 | Port Alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=port alfred
# Processing Record 22 | Akureyri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=akureyri
# Processing Record 23 | Rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=rikitea
# Processing Record 24 | Albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=albany
# Processing Record 25 | Nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=nikolskoye
# City not found. Skipping...
# Processing Record 26 | Mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=mataura
# Processing Record 27 | Upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=upernavik
# Processing Record 28 | Bethel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=bethel
# Processing Record 29 | Kamaishi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=kamaishi
# Processing Record 30 | Hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=hobart
# Processing Record 31 | Provideniya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=provideniya
# Processing Record 32 | Khuzhir
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=khuzhir
# Processing Record 33 | Yima
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=yima
# City not found. Skipping...
# Processing Record 34 | Nome
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=nome
# City not found. Skipping...
# Processing Record 35 | Alofi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=alofi
# Processing Record 36 | Bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=bredasdorp
# Processing Record 37 | Khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=khatanga
# Processing Record 38 | Santa Cruz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=santa cruz
# Processing Record 39 | Dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=dikson
# Processing Record 40 | Mazagao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=mazagao
# Processing Record 41 | Vilyuysk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=vilyuysk
# Processing Record 42 | Castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=castro
# Processing Record 43 | Kroonstad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=kroonstad
# Processing Record 44 | Viedma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=viedma
# Processing Record 45 | Barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=barrow
# Processing Record 46 | Balikpapan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=balikpapan
# City not found. Skipping...
# Processing Record 47 | Rantepao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=rantepao
# Processing Record 48 | Ilulissat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=ilulissat
# Processing Record 49 | Mahajanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=mahajanga
# Processing Record 50 | Thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=thompson
# Processing Record 51 | Puerto Ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=puerto ayora
# Processing Record 52 | Ponta do Sol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=ponta do sol
# Processing Record 53 | Ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=ushuaia
# Processing Record 54 | Leshukonskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=leshukonskoye
# Processing Record 55 | Russell
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=russell
# Processing Record 56 | Sisimiut
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=sisimiut
# Processing Record 57 | Airai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=airai
# City not found. Skipping...
# Processing Record 58 | Tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=tuktoyaktuk
# Processing Record 59 | Oskarshamn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=oskarshamn
# Processing Record 60 | Severo-Kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=severo-kurilsk
# Processing Record 61 | Lagoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=lagoa
# Processing Record 62 | Qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=qaanaaq
# City not found. Skipping...
# Processing Record 63 | Mar del Plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=mar del plata
# Processing Record 64 | East London
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=east london
# Processing Record 65 | Port Lincoln
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=port lincoln
# Processing Record 66 | Port Elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=port elizabeth
# City not found. Skipping...
# Processing Record 67 | Mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=mahebourg
# Processing Record 68 | Saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=saskylakh
# Processing Record 69 | Constitucion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=constitucion
# Processing Record 70 | Jijiga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=jijiga
# Processing Record 71 | Shubarshi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=shubarshi
# Processing Record 72 | Atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=atuona
# Processing Record 73 | Lorengau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=lorengau
# Processing Record 74 | Saint George
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=saint george
# Processing Record 75 | West Point
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=west point
# Processing Record 76 | Muzhi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=muzhi
# Processing Record 77 | Kroya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=kroya
# Processing Record 78 | Leningradskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=leningradskiy
# Processing Record 79 | Ribeira Grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=ribeira grande
# Processing Record 80 | Aykhal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=aykhal
# Processing Record 81 | New Norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=new norfolk
# Processing Record 82 | Tamandare
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=tamandare
# Processing Record 83 | Loukhi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=loukhi
# Processing Record 84 | Norman Wells
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=norman wells
# City not found. Skipping...
# Processing Record 85 | Irbeyskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=irbeyskoye
# Processing Record 86 | Sinjar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=sinjar
# Processing Record 87 | Kirakira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=kirakira
# Processing Record 88 | Bambous Virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=bambous virieux
# Processing Record 89 | Cabedelo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=cabedelo
# Processing Record 90 | Saint-Francois
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=saint-francois
# Processing Record 91 | Moramanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=moramanga
# Processing Record 92 | Gamba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=gamba
# Processing Record 93 | Lena
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=lena
# Processing Record 94 | Adeje
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=adeje
# Processing Record 95 | Panlaitan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=panlaitan
# City not found. Skipping...
# Processing Record 96 | Victoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=victoria
# Processing Record 97 | Saint-Philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=saint-philippe
# Processing Record 98 | Kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=kapaa
# Processing Record 99 | Faanui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=faanui
# Processing Record 100 | Tocopilla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=tocopilla
# Processing Record 101 | Maldonado
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=maldonado
# Processing Record 102 | Lhokseumawe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=lhokseumawe
# Processing Record 103 | Narsaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=narsaq
# Processing Record 104 | Pitimbu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=pitimbu
# Processing Record 105 | Darab
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=darab
# Processing Record 106 | Sibolga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=sibolga
# City not found. Skipping...
# Processing Record 107 | San Cristobal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=san cristobal
# Processing Record 108 | Bandarbeyla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=bandarbeyla
# Processing Record 109 | Kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=kodiak
# City not found. Skipping...
# Processing Record 110 | Ullapool
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=ullapool
# Processing Record 111 | Kruisfontein
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=kruisfontein
# Processing Record 112 | Whitehorse
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=whitehorse
# Processing Record 113 | Lanzhou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=lanzhou
# City not found. Skipping...
# Processing Record 114 | Ixtapa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=ixtapa
# Processing Record 115 | Ahtopol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=ahtopol
# Processing Record 116 | Concarneau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=concarneau
# Processing Record 117 | Grafton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=grafton
# City not found. Skipping...
# Processing Record 118 | Imbituba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=imbituba
# Processing Record 119 | Aksarka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=aksarka
# Processing Record 120 | Vao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=vao
# Processing Record 121 | Luganville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=luganville
# Processing Record 122 | Havoysund
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=havoysund
# Processing Record 123 | Hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=hithadhoo
# Processing Record 124 | Mayo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=mayo
# Processing Record 125 | Luderitz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=luderitz
# Processing Record 126 | Cherskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=cherskiy
# Processing Record 127 | Bathsheba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=bathsheba
# Processing Record 128 | Bambanglipuro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=bambanglipuro
# City not found. Skipping...
# Processing Record 129 | Ushumun
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=ushumun
# Processing Record 130 | Longyearbyen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=longyearbyen
# Processing Record 131 | Margate
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=margate
# Processing Record 132 | Henties Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=henties bay
# City not found. Skipping...
# Processing Record 133 | Noyabrsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=noyabrsk
# Processing Record 134 | Shingu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=shingu
# Processing Record 135 | Sokolo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=sokolo
# Processing Record 136 | Souillac
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=souillac
# Processing Record 137 | Alyangula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=alyangula
# Processing Record 138 | Hambantota
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=hambantota
# Processing Record 139 | Castelnaudary
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=castelnaudary
# City not found. Skipping...
# Processing Record 140 | Beroroha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=beroroha
# Processing Record 141 | Silveira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=silveira
# City not found. Skipping...
# Processing Record 142 | Port Hardy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=port hardy
# Processing Record 143 | Birao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=birao
# Processing Record 144 | Riyadh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=riyadh
# City not found. Skipping...
# Processing Record 145 | Petropavlovsk-Kamchatskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=petropavlovsk-kamchatskiy
# Processing Record 146 | Amapa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=amapa
# Processing Record 147 | Chara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=chara
# Processing Record 148 | Clyde River
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=clyde river
# Processing Record 149 | Carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=carnarvon
# Processing Record 150 | Hobyo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=hobyo
# Processing Record 151 | Cidreira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=cidreira
# Processing Record 152 | Punta Arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=punta arenas
# Processing Record 153 | Aksarayskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=aksarayskiy
# Processing Record 154 | Cheyenne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=cheyenne
# City not found. Skipping...
# Processing Record 155 | Paka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=paka
# Processing Record 156 | Jackville
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=jacqueville
# Processing Record 157 | Chongwe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=chongwe
# Processing Record 158 | Carmen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=carmen
# City not found. Skipping...
# Processing Record 159 | Junin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=junin
# City not found. Skipping...
# Processing Record 160 | Puerto Cabezas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=puerto cabezas
# Processing Record 161 | Pundaguitan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=pundaguitan
# Processing Record 162 | Nanortalik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=nanortalik
# Processing Record 163 | Almaznyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=almaznyy
# Processing Record 164 | Lebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=lebu
# Processing Record 165 | Quelimane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=quelimane
# Processing Record 166 | Yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=yellowknife
# Processing Record 167 | Inhambane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=inhambane
# Processing Record 168 | General Roca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=general roca
# City not found. Skipping...
# Processing Record 169 | Vardo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=vardo
# Processing Record 170 | Georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=georgetown
# Processing Record 171 | Sao Joao da Barra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=sao joao da barra
# Processing Record 172 | Suntar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=suntar
# Processing Record 173 | Tuatapere
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=tuatapere
# City not found. Skipping...
# Processing Record 174 | Salme
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=salme
# Processing Record 175 | Komsomolskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=komsomolskiy
# Processing Record 176 | Saint-Esteve
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=saint-esteve
# City not found. Skipping...
# Processing Record 177 | Arraial do Cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=arraial do cabo
# Processing Record 178 | Vryburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=vryburg
# Processing Record 179 | Avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=avarua
# Processing Record 180 | Kaeo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=kaeo
# Processing Record 181 | Kahului
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=kahului
# Processing Record 182 | Benguela
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=benguela
# Processing Record 183 | Hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=hermanus
# Processing Record 184 | Vila Velha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=vila velha
# Processing Record 185 | Belyy Yar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=belyy yar
# Processing Record 186 | Iqaluit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=iqaluit
# Processing Record 187 | Nueva Helvecia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=nueva helvecia
# Processing Record 188 | Ahipara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=ahipara
# City not found. Skipping...
# Processing Record 189 | Toamasina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=toamasina
# Processing Record 190 | Torbay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=torbay
# Processing Record 191 | Kiama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=kiama
# Processing Record 192 | Biak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=biak
# Processing Record 193 | Mount Gambier
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=mount gambier
# Processing Record 194 | Fortuna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=fortuna
# Processing Record 195 | Salalah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=salalah
# Processing Record 196 | Campbellton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=campbellton
# Processing Record 197 | Kavaratti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=kavaratti
# Processing Record 198 | Nacozari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=nacozari
# Processing Record 199 | Baruun-Urt
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=baruun-urt
# Processing Record 200 | Chapais
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=chapais
# Processing Record 201 | Vila Franca do Campo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=vila franca do campo
# Processing Record 202 | Buenos Aires
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=buenos aires
# Processing Record 203 | Geraldton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=geraldton
# Processing Record 204 | Pevek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=pevek
# Processing Record 205 | Mujiayingzi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=mujiayingzi
# Processing Record 206 | Vestmannaeyjar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=vestmannaeyjar
# Processing Record 207 | Najran
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=najran
# Processing Record 208 | Pochutla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=pochutla
# Processing Record 209 | Los Llanos de Aridane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=los llanos de aridane
# Processing Record 210 | San Patricio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=san patricio
# Processing Record 211 | Wagga Wagga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=wagga wagga
# Processing Record 212 | Shetpe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=shetpe
# Processing Record 213 | Tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=tasiilaq
# Processing Record 214 | Ulfborg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=ulfborg
# Processing Record 215 | Hay River
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=hay river
# Processing Record 216 | Clevelandia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=clevelandia
# Processing Record 217 | Abnub
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=abnub
# Processing Record 218 | Vinh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=vinh
# Processing Record 219 | Zhangye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=zhangye
# Processing Record 220 | Joshimath
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=joshimath
# Processing Record 221 | Sibu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=sibu
# Processing Record 222 | Cabo San Lucas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=cabo san lucas
# Processing Record 223 | Lukovetskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=lukovetskiy
# City not found. Skipping...
# Processing Record 224 | Rimbey
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=rimbey
# Processing Record 225 | Brusque
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=brusque
# Processing Record 226 | Chiniot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=chiniot
# City not found. Skipping...
# Processing Record 227 | Saldanha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=saldanha
# Processing Record 228 | Cabrero
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=cabrero
# Processing Record 229 | Mmabatho
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=mmabatho
# Processing Record 230 | Biu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=biu
# Processing Record 231 | Chenghai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=chenghai
# Processing Record 232 | Cayenne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=cayenne
# Processing Record 233 | Kieta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=kieta
# Processing Record 234 | Conde
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=conde
# Processing Record 235 | Gimbi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=gimbi
# Processing Record 236 | Auki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=auki
# Processing Record 237 | Pacific Grove
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=pacific grove
# Processing Record 238 | Southbridge
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=southbridge
# Processing Record 239 | Yulara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=yulara
# Processing Record 240 | Rubizhne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=rubizhne
# Processing Record 241 | Puerto Escondido
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=puerto escondido
# Processing Record 242 | Haines Junction
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=haines junction
# Processing Record 243 | Tautira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=tautira
# Processing Record 244 | Nianzishan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=nianzishan
# Processing Record 245 | Ayagoz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=ayagoz
# Processing Record 246 | Jiuquan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=jiuquan
# Processing Record 247 | Piacabucu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=piacabucu
# Processing Record 248 | Dwarka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=dwarka
# Processing Record 249 | Batemans Bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=batemans bay
# Processing Record 250 | Aksu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=aksu
# Processing Record 251 | Aasiaat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=aasiaat
# Processing Record 252 | Chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=chokurdakh
# Processing Record 253 | Sao Filipe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=sao filipe
# Processing Record 254 | Amazar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=amazar
# Processing Record 255 | Pavino
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=pavino
# Processing Record 256 | Takoradi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=takoradi
# Processing Record 257 | Urusha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=urusha
# Processing Record 258 | Sitka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=sitka
# Processing Record 259 | Kaitangata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=kaitangata
# Processing Record 260 | Kuybysheve
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=kuybysheve
# Processing Record 261 | Phan Thiet
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=phan thiet
# Processing Record 262 | Saint-Pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=saint-pierre
# City not found. Skipping...
# Processing Record 263 | Kano
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=kano
# Processing Record 264 | Namibe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=namibe
# Processing Record 265 | Dhidhdhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=dhidhdhoo
# Processing Record 266 | Pangnirtung
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=pangnirtung
# Processing Record 267 | Hamilton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=hamilton
# Processing Record 268 | Meulaboh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=meulaboh
# City not found. Skipping...
# Processing Record 269 | Hasaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=hasaki
# Processing Record 270 | Rawson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=rawson
# Processing Record 271 | Khani
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=khani
# Processing Record 272 | Omsukchan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=omsukchan
# Processing Record 273 | Leh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=leh
# Processing Record 274 | Sarishabari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=sarishabari
# City not found. Skipping...
# Processing Record 275 | Kindu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=kindu
# Processing Record 276 | Coquimbo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=coquimbo
# Processing Record 277 | Naze
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=naze
# Processing Record 278 | Dongying
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=dongying
# Processing Record 279 | Severnoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=severnoye
# Processing Record 280 | Padrauna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=padrauna
# Processing Record 281 | Bonavista
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=bonavista
# Processing Record 282 | Portland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=portland
# City not found. Skipping...
# Processing Record 283 | Chuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=chuy
# Processing Record 284 | Ballina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=ballina
# Processing Record 285 | Launceston
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=launceston
# Processing Record 286 | Warrington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=warrington
# City not found. Skipping...
# Processing Record 287 | Carutapera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=carutapera
# Processing Record 288 | Tandil
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=tandil
# Processing Record 289 | Tecoanapa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=tecoanapa
# Processing Record 290 | Gorontalo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=gorontalo
# Processing Record 291 | Zyryanovsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=zyryanovsk
# Processing Record 292 | Kilimatinde
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=kilimatinde
# Processing Record 293 | Canico
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=canico
# Processing Record 294 | Carahue
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=carahue
# Processing Record 295 | Yarada
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=yarada
# Processing Record 296 | Opuwo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=opuwo
# Processing Record 297 | Kalemie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=kalemie
# Processing Record 298 | Gotsu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=gotsu
# Processing Record 299 | Ravar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=ravar
# Processing Record 300 | Channel-Port aux Basques
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=channel-port aux basques
# Processing Record 301 | Coahuayana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=coahuayana
# Processing Record 302 | Kalat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=kalat
# Processing Record 303 | BELLAVISTA
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=bellavista
# Processing Record 304 | Lasa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=lasa
# City not found. Skipping...
# Processing Record 305 | Daru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=daru
# Processing Record 306 | Sterling
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=sterling
# Processing Record 307 | Makakilo City
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=makakilo city
# Processing Record 308 | Lawton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=lawton
# City not found. Skipping...
# Processing Record 309 | Puerto Lleras
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=puerto lleras
# Processing Record 310 | Nikolsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=nikolsk
# Processing Record 311 | Parrita
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=parrita
# Processing Record 312 | Mporokoso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=mporokoso
# Processing Record 313 | Kupang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=kupang
# City not found. Skipping...
# Processing Record 314 | Menongue
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=menongue
# Processing Record 315 | Jining
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=jining
# Processing Record 316 | Stillwater
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=stillwater
# Processing Record 317 | Thinadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=thinadhoo
# Processing Record 318 | Mao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=mao
# Processing Record 319 | Miri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=miri
# Processing Record 320 | Ekhabi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=ekhabi
# Processing Record 321 | Ancud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=ancud
# Processing Record 322 | Sobolevo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=sobolevo
# City not found. Skipping...
# Processing Record 323 | Avera
# ...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=huarmey
# Processing Record 449 | Zvishavane
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=zvishavane
# Processing Record 450 | Huilong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=huilong
# Processing Record 451 | Moscow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=moscow
# Processing Record 452 | Tessalit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=tessalit
# Processing Record 453 | Caravelas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=caravelas
# Processing Record 454 | Juneau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=juneau
# Processing Record 455 | Langnau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=langnau
# Processing Record 456 | Lethem
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=lethem
# Processing Record 457 | Lusambo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=lusambo
# Processing Record 458 | Gawler
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=gawler
# Processing Record 459 | Karasburg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=karasburg
# Processing Record 460 | Vila do Maio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=vila do maio
# City not found. Skipping...
# Processing Record 461 | Moron
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=moron
# Processing Record 462 | Lubao
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=lubao
# Processing Record 463 | Northam
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=northam
# Processing Record 464 | Bajil
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=bajil
# Processing Record 465 | Ilheus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=ilheus
# Processing Record 466 | Natal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=natal
# Processing Record 467 | Kamenka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=kamenka
# Processing Record 468 | Champerico
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=champerico
# City not found. Skipping...
# Processing Record 469 | Hutchinson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=hutchinson
# Processing Record 470 | Kilosa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=kilosa
# Processing Record 471 | Kushima
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=kushima
# Processing Record 472 | Anadyr
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=anadyr
# Processing Record 473 | Grand Baie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=grand baie
# Processing Record 474 | Grand-Lahou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=grand-lahou
# Processing Record 475 | Bubaque
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=bubaque
# Processing Record 476 | Erenhot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=erenhot
# Processing Record 477 | Koryazhma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=koryazhma
# Processing Record 478 | Noumea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=noumea
# Processing Record 479 | Havre-Saint-Pierre
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=havre-saint-pierre
# Processing Record 480 | Ponta Delgada
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=ponta delgada
# Processing Record 481 | Esperance
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=esperance
# Processing Record 482 | Sattahip
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=sattahip
# Processing Record 483 | Fort Morgan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=fort morgan
# Processing Record 484 | Bosaso
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=bosaso
# Processing Record 485 | Cazones
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=cazones
# Processing Record 486 | Mwinilunga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=mwinilunga
# Processing Record 487 | Dingle
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=dingle
# Processing Record 488 | Mangan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=mangan
# Processing Record 489 | Bonfim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=bonfim
# Processing Record 490 | Tilichiki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=tilichiki
# Processing Record 491 | Burnie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=burnie
# Processing Record 492 | Oksfjord
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=oksfjord
# City not found. Skipping...
# Processing Record 493 | Solnechnyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=solnechnyy
# Processing Record 494 | Krasnyy Chikoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=krasnyy chikoy
# Processing Record 495 | Zhigalovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=zhigalovo
# Processing Record 496 | Mokobeng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=mokobeng
# Processing Record 497 | Bonoua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=bonoua
# Processing Record 498 | Edd
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=edd
# Processing Record 499 | Okhotsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=okhotsk
# Processing Record 500 | Coihaique
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=coihaique
# Processing Record 501 | Belmonte
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=belmonte
# Processing Record 502 | Bamberg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=bamberg
# City not found. Skipping...
# Processing Record 503 | Marawi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=marawi
# Processing Record 504 | Cap Malheureux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=cap malheureux
# Processing Record 505 | Reforma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=reforma
# Processing Record 506 | Masvingo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=masvingo
# Processing Record 507 | Parole
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=parole
# Processing Record 508 | Sovetskaya Gavan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=sovetskaya gavan
# City not found. Skipping...
# Processing Record 509 | Jati
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=jati
# Processing Record 510 | Saint-Ambroise
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=saint-ambroise
# Processing Record 511 | Buala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=buala
# Processing Record 512 | Aklavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=aklavik
# Processing Record 513 | Harrislee
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=harrislee
# Processing Record 514 | Matay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=matay
# Processing Record 515 | Dogondoutchi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=dogondoutchi
# Processing Record 516 | Manadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=manadhoo
# Processing Record 517 | Dongsheng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=dongsheng
# Processing Record 518 | Haapiti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=haapiti
# Processing Record 519 | Manta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=manta
# Processing Record 520 | Srednekolymsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=srednekolymsk
# Processing Record 521 | Tsumeb
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=tsumeb
# Processing Record 522 | Surt
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=surt
# Processing Record 523 | San Marcos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=san marcos
# Processing Record 524 | Lucapa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=lucapa
# Processing Record 525 | Bonthe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=bonthe
# Processing Record 526 | Troitsko-Pechorsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=troitsko-pechorsk
# Processing Record 527 | Minna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=minna
# Processing Record 528 | Namatanai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=namatanai
# Processing Record 529 | Taltal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=taltal
# Processing Record 530 | Sur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=sur
# Processing Record 531 | Jinchang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=jinchang
# City not found. Skipping...
# Processing Record 532 | Amahai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=amahai
# Processing Record 533 | Rapina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=rapina
# City not found. Skipping...
# Processing Record 534 | Vostok
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=vostok
# Processing Record 535 | Fez
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=fez
# Processing Record 536 | Kalabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=kalabo
# Processing Record 537 | Proletariy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=proletariy
# Processing Record 538 | Safranbolu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=safranbolu
# Processing Record 539 | Alice Springs
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=alice springs
# Processing Record 540 | Tanout
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=tanout
# Processing Record 541 | San Rafael
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=san rafael
# Processing Record 542 | Kanniyakumari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=kanniyakumari
# Processing Record 543 | Wangqing
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=wangqing
# Processing Record 544 | Hanchuan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=hanchuan
# Processing Record 545 | Lisakovsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=lisakovsk
# Processing Record 546 | Moindou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=moindou
# Processing Record 547 | Kantang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=kantang
# Processing Record 548 | Mount Pleasant
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=mount pleasant
# Processing Record 549 | Hualmay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=hualmay
# Processing Record 550 | Mogadishu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=mogadishu
# Processing Record 551 | Kalmunai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=kalmunai
# Processing Record 552 | Alta Floresta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=alta floresta
# Processing Record 553 | Mbeya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=mbeya
# Processing Record 554 | Faya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=faya
# Processing Record 555 | The Valley
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=the valley
# Processing Record 556 | Kandrian
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7f67c78627c62ce245c39367d6ec692e&q=kandrian

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %%
weather_data_dict = {
    "City Name": city_name, 
    "Cloudiness": cloudiness,
    "Country": country,
    "Date": date,
    "Humidity": humidity,
    "Lat": lat,
    "Lng": lng,
    "Max Temp": max_temp,
    "Wind Speed": wind_speed
}
                   
# Create a data frame from dictionary
weather_data = pd.DataFrame(weather_data_dict)

# Display count of weather data values 
weather_data.count()
# Out:
# City Name     556
# Cloudiness    556
# Country       556
# Date          556
# Humidity      556
# Lat           556
# Lng           556
# Max Temp      556
# Wind Speed    556
# dtype: int64

# %%
#Save weather data to csv
weather_data.to_csv('../PythonAPI/weather_data.csv')

weather_data.head()
# Out:
#     City Name  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0   Matamoros          75      US  1559530249        74  25.87  -97.51
# 1   Busselton           9      AU  1559530250        31 -33.64  115.35
# 2        Poum          99      MK  1559529789        94  41.28   20.71
# 3  Codrington          75      AU  1559529672        56 -28.95  153.24
# 4   Cape Town           0      ZA  1559530254        93 -33.93   18.42
#
#    Max Temp  Wind Speed
# 0     82.99        8.05
# 1     63.00       17.09
# 2     47.61        3.80
# 3     69.01       13.87
# 4     61.00        6.93

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Max Temp"], marker="o", s = max_temp*10, edgecolor="blue", alpha=0.75, linewidth=1.0)

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature(05/31/2019)", weight='semibold',fontsize=14)
plt.xlabel("Lat", weight='semibold',fontsize=12)
plt.ylabel("Max. Temperature (F)", weight='semibold',fontsize=12)
plt.grid(True)

plt.savefig('../PythonAPI/Max_Temp vs. Latitude.png', dpi=150)


plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Humidity"], marker="o", s= humidity*10, edgecolor="blue", alpha=0.75, linewidth=1.0)

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity(05/31/2019)", weight='semibold',fontsize=14)
plt.xlabel("Lat", weight='semibold',fontsize=12)
plt.ylabel("Humidity (%)", weight='semibold',fontsize=12)
plt.grid()

# Save the figure
plt.savefig('../PythonAPI/City Latitude vs. Humidity.png', dpi=150)

#Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Cloudiness"], marker="o", s= lat*10, edgecolor="blue", alpha=0.75, linewidth=1.0)

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness(05/31/2019)", weight='semibold',fontsize=14)
plt.xlabel("Lat", weight='semibold', fontsize=12)
plt.ylabel("Cloudiness (%)", weight='semibold', fontsize=12)
plt.grid()

# Save the figure
plt.savefig('../PythonAPI/City Latitude vs. Cloudiness.png', dpi=150)

#Show plot
plt.show()
# Out:
# C:\Users\anoos\Anaconda3\lib\site-packages\matplotlib\collections.py:874: RuntimeWarning: invalid value encountered in sqrt
#   scale = np.sqrt(self._sizes) * dpi / 72.0 * self._factor

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Wind Speed"], marker="o", s= wind_speed*10, edgecolor="blue", alpha=0.75, linewidth=1.0)

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed(05/31/2019)", weight='semibold', fontsize=14)
plt.xlabel("Lat",weight='semibold', fontsize=12)
plt.ylabel("Wind Speed (%)",weight='semibold', fontsize=12)
plt.grid()

# Save the figure
plt.savefig('../PythonAPI/City Latitude vs. Wind Speed.png', dpi=150)

#Show plot
plt.show()
